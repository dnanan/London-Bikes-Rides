# %%
import pandas as pd

# %%
data = pd.read_csv('london_merged.csv')

# %%
data
# Out:
#           timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0       1/4/15 0:00   182  3.0  2.0   93.0         6.0             3
# 1       1/4/15 1:00   138  3.0  2.5   93.0         5.0             1
# 2       1/4/15 2:00   134  2.5  2.5   96.5         0.0             1
# 3       1/4/15 3:00    72  2.0  2.0  100.0         0.0             1
# 4       1/4/15 4:00    47  2.0  0.0   93.0         6.5             1
# ...             ...   ...  ...  ...    ...         ...           ...
# 17409  1/3/17 19:00  1042  5.0  1.0   81.0        19.0             3
# 17410  1/3/17 20:00   541  5.0  1.0   81.0        21.0             4
# 17411  1/3/17 21:00   337  5.5  1.5   78.5        24.0             4
# 17412  1/3/17 22:00   224  5.5  1.5   76.0        23.0             4
# 17413  1/3/17 23:00   139  5.0  1.0   76.0        22.0             2
#
#        is_holiday  is_weekend  season
# 0               0           1       3
# 1               0           1       3
# ...

# %%
# Count the uniques values in the weather_code column
data['weather_code'].value_counts()
# Out:
# 1     6150
# 2     4034
# 3     3551
# 7     2141
# 4     1464
# 26      60
# 10      14
# Name: weather_code, dtype: int64

# %%
# Count the unique values in the season column
data['season'].value_counts()
# Out:
# 0    4394
# 1    4387
# 3    4330
# 2    4303
# Name: season, dtype: int64

# %%
# Specifying the column names that i want to use
news_cols = {
    'timestamp': 'time',
    'cnt': 'count',
    't1': 'temp_real_C',
    't2': 'temp_feels_like_C',
    'hum': 'humidity_percent',
    'wind_speed': 'wind_speed_kph',
    'weather_code': 'weather',
    'is_holiday': 'holiday',
    'is_weekend': 'weekend',
    'season': 'season'
}

# Renaming the column
data.rename(news_cols, axis = 1, inplace = True)

# %%
# Changing the humidity values to percentage (ie values between 0 & 1)
data['humidity_percent'] = data['humidity_percent']/100

# %%
data.head()
# Out:
#           time  count  temp_real_C  temp_feels_like_C  humidity_percent  \
# 0  1/4/15 0:00    182          3.0                2.0             0.930
# 1  1/4/15 1:00    138          3.0                2.5             0.930
# 2  1/4/15 2:00    134          2.5                2.5             0.965
# 3  1/4/15 3:00     72          2.0                2.0             1.000
# 4  1/4/15 4:00     47          2.0                0.0             0.930
#
#    wind_speed_kph  weather  holiday  weekend  season
# 0             6.0        3        0        1       3
# 1             5.0        1        0        1       3
# 2             0.0        1        0        1       3
# 3             0.0        1        0        1       3
# 4             6.5        1        0        1       3

# %%
data.dtypes
# Out:
# time                  object
# count                  int64
# temp_real_C          float64
# temp_feels_like_C    float64
# humidity_percent     float64
# wind_speed_kph       float64
# weather                int64
# holiday                int64
# weekend                int64
# season                 int64
# dtype: object

# %%
# Creating a season dictionary so that we can map the integers 0-3 to the actual written values
season_dict = {
    '0': 'spring',
    '1': 'summer',
    '2': 'fall',
    '3': 'winter'
}

# Creating a weather dictionary so that we can map the integers 0-3 to the actual written values
weather_dict = {
    '1': 'Clear',
    '2': 'Scattered Clouds',
    '3': 'Broken Clouds',
    '4': 'Cloudy',
    '7': 'Rain',
    '10': 'Rain With Thunderstorm',
    '26': 'Snowfall'

}

# %%
# Changing the season column data type to string
data['season'] = data['season'].astype('str')
# Mapping the values 0-3 to the actual written seasons
data['season'] = data['season'].map(season_dict)

# Changing the weather column data type to string
data['weather'] = data['weather'].astype('str')
# Mapping the values to the actual written weathers
data['weather'] = data['weather'].map(weather_dict)

# %%
data.head()
# Out:
#           time  count  temp_real_C  temp_feels_like_C  humidity_percent  \
# 0  1/4/15 0:00    182          3.0                2.0             0.930
# 1  1/4/15 1:00    138          3.0                2.5             0.930
# 2  1/4/15 2:00    134          2.5                2.5             0.965
# 3  1/4/15 3:00     72          2.0                2.0             1.000
# 4  1/4/15 4:00     47          2.0                0.0             0.930
#
#    wind_speed_kph        weather  holiday  weekend  season
# 0             6.0  Broken Clouds        0        1  winter
# 1             5.0          Clear        0        1  winter
# 2             0.0          Clear        0        1  winter
# 3             0.0          Clear        0        1  winter
# 4             6.5          Clear        0        1  winter

# %%
# Writing the final data frame to an Excel file that we will use in tableau visualizations. The file will be the 'London_bikes_final"
data.to_excel('London_bikes_final.xlsx', sheet_name= 'Data')
